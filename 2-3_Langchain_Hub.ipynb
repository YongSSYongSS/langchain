# %% [markdown]
# **Langchain hub**

# %%
from langchain import hub

# Langchain에서 hub.pull실행 시 Langchain hub라는 중앙 저장소에서 프롬프트를 불러옴  https://smith.langchain.com/hub/rlm/rag-prompt
prompt = hub.pull("rlm/rag-prompt") 

prompt
# Out:
# c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
prompt = hub.pull("rlm/rag-prompt:50442af1")
prompt
# Out:
# c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})])

# %% [markdown]
# Prompt Hub에 자신의 프롬프트 등록

# %%
from langchain.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_template(
    "주어진 내용을 바탕으로 다음 문장을 요약하세요. 답변은 반드시 한글로 작성하세요\n\nCONTEXT: {context}\n\nSUMMARY:"
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='주어진 내용을 바탕으로 다음 문장을 요약하세요. 답변은 반드시 한글로 작성하세요\n\nCONTEXT: {context}\n\nSUMMARY:'), additional_kwargs={})])

# %%
from langchain import hub

# 프롬프트를 허브에 업로드합니다.
hub.push("teddynote/simple-summary-korean", prompt)
# Out:
# c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\utils.py:150, in raise_for_status_with_text(response)
#     149 try:
# --> 150     response.raise_for_status()
#     151 except requests.HTTPError as e:
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.smith.langchain.com/settings
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:763, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     753     response = self.session.request(
#     754         method,
#     755         (
#    (...)    761         **request_kwargs,
#     762     )
# --> 763 ls_utils.raise_for_status_with_text(response)
#     764 return response
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\utils.py:152, in raise_for_status_with_text(response)
#     151 except requests.HTTPError as e:
# --> 152     raise requests.HTTPError(str(e), response.text) from e
#
# HTTPError: [Errno 401 Client Error: Unauthorized for url: https://api.smith.langchain.com/settings] {"detail":"Invalid token"}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithAuthError                        Traceback (most recent call last)
# Cell In[13], line 4
#       1 from langchain import hub
#       3 # 프롬프트를 허브에 업로드합니다.
# ----> 4 hub.push("teddynote/simple-summary-korean", prompt)
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langchain\hub.py:71, in push(repo_full_name, object, api_url, api_key, parent_commit_hash, new_repo_is_public, new_repo_description, readme, tags)
#      69 # Then it's langsmith
#      70 if hasattr(client, "push_prompt"):
# ---> 71     return client.push_prompt(
#      72         repo_full_name,
#      73         object=object,
#      74         parent_commit_hash=parent_commit_hash,
#      75         is_public=new_repo_is_public,
#      76         description=new_repo_description,
#      77         readme=readme,
#      78         tags=tags,
#      79     )
#      81 # Then it's langchainhub
#      82 manifest_json = dumps(object)
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:5771, in Client.push_prompt(self, prompt_identifier, object, parent_commit_hash, is_public, description, readme, tags)
#    5767 if self._prompt_exists(prompt_identifier):
#    5768     if any(
#    5769         param is not None for param in [is_public, description, readme, tags]
#    5770     ):
# -> 5771         self.update_prompt(
#    5772             prompt_identifier,
#    5773             description=description,
#    5774             readme=readme,
#    5775             tags=tags,
#    5776             is_public=is_public,
#    5777         )
#    5778 else:
#    5779     self.create_prompt(
#    5780         prompt_identifier,
#    5781         is_public=is_public if is_public is not None else False,
#    (...)   5784         tags=tags,
#    5785     )
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:5475, in Client.update_prompt(self, prompt_identifier, description, readme, tags, is_public, is_archived)
#    5446 def update_prompt(
#    5447     self,
#    5448     prompt_identifier: str,
#    (...)   5454     is_archived: Optional[bool] = None,
#    5455 ) -> Dict[str, Any]:
#    5456     """Update a prompt's metadata.
#    5457
#    5458     To update the content of a prompt, use push_prompt or create_commit instead.
#    (...)   5473         HTTPError: If the server request fails.
#    5474     """
# -> 5475     settings = self._get_settings()
#    5476     if is_public and not settings.tenant_handle:
#    5477         raise ValueError(
#    5478             "Cannot create a public prompt without first\n"
#    5479             "creating a LangChain Hub handle. "
#    5480             "You can add a handle by creating a public prompt at:\n"
#    5481             "https://smith.langchain.com/prompts"
#    5482         )
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:641, in Client._get_settings(self)
#     635 """Get the settings for the current tenant.
#     636
#     637 Returns:
#     638     dict: The settings for the current tenant.
#     639 """
#     640 if self._settings is None:
# --> 641     response = self.request_with_retries("GET", "/settings")
#     642     ls_utils.raise_for_status_with_text(response)
#     643     self._settings = ls_schemas.LangSmithSettings(**response.json())
#
# File c:\Users\GoodusData\Desktop\공부\langchain\1lecture\Lib\site-packages\langsmith\client.py:798, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     793     raise ls_utils.LangSmithRateLimitError(
#     794         f"Rate limit exceeded for {pathname}. {repr(e)}"
#     795         f"{_context}"
#     796     )
#     797 elif response.status_code == 401:
# --> 798     raise ls_utils.LangSmithAuthError(
#     799         f"Authentication failed for {pathname}. {repr(e)}"
#     800         f"{_context}"
#     801     )
#     802 elif response.status_code == 404:
#     803     raise ls_utils.LangSmithNotFoundError(
#     804         f"Resource not found for {pathname}. {repr(e)}"
#     805         f"{_context}"
#     806     )
#
# LangSmithAuthError: Authentication failed for /settings. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/settings', '{"detail":"Invalid token"}')
